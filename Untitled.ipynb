# %%
#!/bin/python3

import math
import os
import random
import re
import sys



#
# Complete the 'maxDistinctSubstringLengthInSessions' function below.
#
# The function is expected to return an INTEGER.
# The function accepts STRING sessionString as parameter.
#

def maxDistinctSubstringLengthInSessions(sessionString):
    dictionary = {}
    left = 0
    max_length = 0

    for right in range(len(sessionString)):
        char = sessionString[right]
        print(char)

        # If character is already in dictionary and inside current window
        if char in dictionary and dictionary[char] >= left:
            left = dictionary[char] + 1
            print(dictionary,left,"old")

        # Update last seen index
        dictionary[char] = right
        print(dictionary,right,"new")

        # Calculate window length
        max_length = max(max_length, right - left + 1)

    return dictionary,max_length

if __name__ == '__main__':
    sessionString = input()

    result = maxDistinctSubstringLengthInSessions(sessionString)

    print(result)
# Out:
#  abcdaa
# a
# {'a': 0} 0 new
# b
# {'a': 0, 'b': 1} 1 new
# c
# {'a': 0, 'b': 1, 'c': 2} 2 new
# d
# {'a': 0, 'b': 1, 'c': 2, 'd': 3} 3 new
# a
# {'a': 0, 'b': 1, 'c': 2, 'd': 3} 1 old
# {'a': 4, 'b': 1, 'c': 2, 'd': 3} 4 new
# a
# {'a': 4, 'b': 1, 'c': 2, 'd': 3} 5 old
# {'a': 5, 'b': 1, 'c': 2, 'd': 3} 5 new
# ({'a': 5, 'b': 1, 'c': 2, 'd': 3}, 4)

# %%
conda install jedi
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: -
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 26.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - jedi
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2026.01.04         |  py313hca03da5_0         148 KB
#     ------------------------------------------------------------
#                                            Total:         148 KB
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.2.25-hca03da5_0 --> 2025.12.2-hca03da5_0
# ...

# %%
strs = "abccefd"
dictionary = {}
for right in len(str(strs)):
    char = strs[right]

# %%
# !pip install jupyter_contrib_nbextensions
# !jupyter contrib nbextension install --user
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 12.0 MB/s eta 0:00:00 MB/s eta 0:00:0102
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: Building 'jupyter_contrib_nbextensions' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'jupyter_contrib_nbextensions'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for jupyter_contrib_nbextensions: filename=jupyter_contrib_nbextensions-0.7.0-py2.py3-none-any.whl size=23428768 sha256=4eaf57f7afb212d5cf7904496f716ab3b05de26b22631fb250409d3f1cc6ebc6
# ...

# %%
# !pip install "python-lsp-server[all]"

# %%
for i,j in enumerate(10):
    print(i,j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 for i,j in enumerate(10):
#       2     print(i,j)
#
# TypeError: 'int' object is not iterable
